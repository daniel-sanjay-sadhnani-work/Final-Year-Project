# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("UpdatedStudentSurvey.csv" , encoding='ISO-8859-1')
df
# Out:
#      Gender  Age Ethnicity   Religion Parents Work  Siblings      Housing  \
# 0      Male   19   Chinese   Buddhist   Both Works         2          HDB
# 1      Male   21   Chinese   Buddhist   Both Works         2          HDB
# 2      Male   19   Chinese   Buddhist  Father Only         2  Condominium
# 3      Male   22   Chinese   Catholic   Both Works         2     Bungalow
# 4      Male   19   Chinese   Buddhist   Both Works         1          HDB
# ..      ...  ...       ...        ...          ...       ...          ...
# 196  Female   19    Indian      Islam   Both Works         2          HDB
# 197    Male   19   Chinese   Buddhist  Mother Only         2          HDB
# 198  Female   19   Chinese  Christian   Both Works         2  Condominium
# 199  Female   24   Chinese  Christian  Mother Only         4          HDB
# 200  Female   20     Malay      Islam  Father Only         1  Maisonnette
#
#      Current GPA  Desired GPA  Absences  ... Future Planned Career Option 1  \
# 0           2.71         2.86         0  ...        Not yet             Nan
# 1           0.98         1.50         6  ...        Not yet             Nan
# 2           2.86         3.30         0  ...        Not yet             Nan
# 3           3.10         4.00         7  ...      Undecided             Nan
# 4           3.00         3.50         1  ...      Undecided             Nan
# ..           ...          ...       ...  ...            ...             ...
# 196         3.45         3.60         3  ...        Not yet             Nan
# 197         2.90         3.50         0  ...      Undecided             Nan
# 198         2.40         3.00         1  ...        Not yet             Nan
# 199         1.81         2.50         0  ...        Planned           Nurse
# 200         3.03         3.70         2  ...      Undecided             Nan
#
#     Career Option 2 Career Option 3  Interested Career 1 Interested Career 2  \
# 0               Nan             Nan  Software Developer          Ai Analyst
# 1               Nan             Nan                  Nan                 Nan
# 2               Nan             Nan        Entrepreneur       Food Reviewer
# 3               Nan             Nan                  Nan                 Nan
# 4               Nan             Nan             Engineer                 Nan
# ..              ...             ...                  ...                 ...
# 196             Nan             Nan              Teacher        Hospital Lab
# 197             Nan             Nan          Translator            Reporter
# 198             Nan             Nan                  Nan                 Nan
# 199      Journalist             Nan                  Nan                 Nan
# 200             Nan             Nan                  Nan                 Nan
#
#       Interested Career 3      Skill 1            Skill 2  \
# 0    Cybersecurity Expert        Code           Detailed
# 1                     Nan          Nan                Nan
# 2            Food Vlogger  Innovative           Critical
# 3                     Nan     Detailed                Nan
# 4                     Nan          Nan                Nan
# ..                    ...          ...                ...
# 196            Pharmacist    Precision  Laboratory Skills
# 197    Sports Commentator    Language          Outspoken
# 198                   Nan          Nan                Nan
# 199                   Nan     Patience     Writing Skills
# 200                   Nan          Nan                Nan
#
#                   Skill 3
# 0               Adaptable
# 1                     Nan
# 2            Entertaining
# 3                     Nan
# 4                     Nan
# ..                    ...
# 196            Timeliness
# 197            Confidence
# 198                   Nan
# 199  Communication Skills
# 200                   Nan
#
# [201 rows x 41 columns]

# %%
main_categories = ['Results', 'Study Life', 'None', 'Social Life', 'Lecturers', 'Classmates', 'Courses']

# Ensure 'None' is treated as a separate category and not grouped with 'Others'
df['Unsatisfied Area Modified'] = df['Unsatisfied Area'].apply(lambda x: x if x in main_categories else 'Others')

# Recalculate the value counts for the modified column
modified_unsatisfied_counts = df['Unsatisfied Area Modified'].value_counts()

# Pie Chart
plt.figure(figsize=(5, 5))
plt.pie(modified_unsatisfied_counts, labels=modified_unsatisfied_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Percentages of Unsatisfied Areas with Grouped Categories')
plt.axis('equal') 
plt.show()

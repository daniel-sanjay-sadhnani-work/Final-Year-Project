# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("FYP_Student_Survey.xlsx")
df
# Out:
#      Gender  Age Tertiary Education Ethnicity     Religion Parents Work  \
# 0      Male   19        Polytechnic   Chinese     Buddhist   Both Works
# 1      Male   21        Polytechnic   Chinese     Buddhist   Both Works
# 2      Male   19        Polytechnic   Chinese     Buddhist  Father Only
# 3      Male   22        Polytechnic   Chinese     Catholic   Both Works
# 4      Male   19        Polytechnic   Chinese  skin walker  Mother Only
# ..      ...  ...                ...       ...          ...          ...
# 197  Female   19        Polytechnic    Indian        Islam   Both Works
# 198    Male   19        Polytechnic   Chinese     Buddhist  Mother Only
# 199  Female   19        Polytechnic   Chinese    Christian   Both Works
# 200  Female   24        Polytechnic   Chinese    Christian  Mother Only
# 201  Female   20        Polytechnic     Malay        Islam  Father Only
#
#      Siblings      Housing  Current GPA  Desired GPA  ...  Future Planned  \
# 0           2          HDB         2.71         2.86  ...         Not yet
# 1           2          HDB         0.98         1.50  ...         Not yet
# 2           2  Condominium         2.86         3.30  ...         Not yet
# 3           2     Bungalow         3.10         4.00  ...       Undecided
# 4           1          HDB         1.96         2.80  ...       Undecided
# ..        ...          ...          ...          ...  ...             ...
# 197         2          HDB         3.45         3.60  ...         Not yet
# 198         2          HDB         2.90         3.50  ...       Undecided
# 199         2  Condominium         2.40         3.00  ...         Not yet
# 200         4          HDB         1.81         2.50  ...         Planned
# 201         1  Maisonnette         3.03         3.70  ...       Undecided
#
#     Career Option 1 Career Option 2 Career Option 3  Interested Career 1  \
# 0               NaN             NaN             NaN  Software developer
# 1               NaN             NaN             NaN                  NaN
# 2               NaN             NaN             NaN        Entrepreneur
# 3               NaN             NaN             NaN             Not sure
# 4               NaN             NaN             NaN                  NaN
# ..              ...             ...             ...                  ...
# 197             NaN             NaN             NaN              Teacher
# 198             NaN             NaN             NaN          Translator
# 199             NaN             NaN             NaN                  NaN
# 200           nurse      journalist             NaN                  NaN
# 201             NaN             NaN             NaN                  NIL
#
#     Interested Career 2   Interested Career 3      Skill 1            Skill 2  \
# 0           Ai analyst   Cybersecurity expert        Code           Detailed
# 1                   NaN                   NaN          NaN                NaN
# 2        Food Reviewer           Food vlogger  Innovative           Critical
# 3                   NaN                   NaN     Detailds                NaN
# 4                   NaN                   NaN          NaN                NaN
# ..                  ...                   ...          ...                ...
# 197        hospital Lab            pharmacist    Precision  laboratory skills
# 198           Reporter     Sports Commentator    Language          Outspoken
# 199                 NaN                   NaN          NaN                NaN
# 200                 NaN                   NaN     patience     writing skills
# 201                 NaN                   NaN          NaN                NaN
#
#                   Skill 3
# 0               Adaptable
# 1                     NaN
# 2            Entertaining
# 3                     NaN
# 4                     NaN
# ..                    ...
# 197            timeliness
# 198            Confidence
# 199                   NaN
# 200  communication skills
# 201                   NaN
#
# [202 rows x 42 columns]

# %%
avg_gpa = df.groupby('Game Hours')['Current GPA'].mean().reset_index()
print("Average GPA for each Game Hours group:")
print(avg_gpa)

filtered_avg_gpa = avg_gpa[avg_gpa['Current GPA'] > 3.00]
print("Filtered Average GPA (higher than 3.00):")
print(filtered_avg_gpa)

sorted_filtered_avg_gpa = filtered_avg_gpa.sort_values(by='Current GPA', ascending=False)
print("Sorted Filtered Average GPA (in descending order):")
print(sorted_filtered_avg_gpa)

if not filtered_avg_gpa.empty:
    sorted_filtered_avg_gpa = filtered_avg_gpa.sort_values(by='Current GPA', ascending=False)
    sorted_filtered_avg_gpa.plot(kind='bar', x='Game Hours', y='Current GPA', legend=False)
    plt.title('Average GPA by Game Hours')
    plt.xlabel('Game Hours')
    plt.ylabel('Average GPA')
    plt.show()
else:
    print("No Game Hours with an average GPA higher than 3.00.")
# Out:
# Average GPA for each Game Hours group:
#                Game Hours  Current GPA
# 0                 10 - 19     3.033171
# 1                 20 - 29     3.090000
# 2                 30 - 39     3.001429
# 3                 40 - 49     2.960833
# 4                 50 - 59     2.443333
# 5                 60 - 69     2.690000
# 6                 70 - 84     3.080000
# 7                     < 9     2.746591
# 8                    > 84     2.528889
# 9  Don't Play Video Games     2.830189
# Filtered Average GPA (higher than 3.00):
#   Game Hours  Current GPA
# 0    10 - 19     3.033171
# 1    20 - 29     3.090000
# 2    30 - 39     3.001429
# 6    70 - 84     3.080000
# Sorted Filtered Average GPA (in descending order):
#   Game Hours  Current GPA
# 1    20 - 29     3.090000
# 6    70 - 84     3.080000
# 0    10 - 19     3.033171
# 2    30 - 39     3.001429

# %%
avg_gpa = df.groupby('Part-Time Hours')['Current GPA'].mean().reset_index()
print("Average GPA for each Part-Time Hours group:")
print(avg_gpa)

filtered_avg_gpa = avg_gpa[avg_gpa['Current GPA'] > 3.00]
print("Filtered Average GPA (higher than 3.00):")
print(filtered_avg_gpa)

sorted_filtered_avg_gpa = filtered_avg_gpa.sort_values(by='Current GPA', ascending=False)
print("Sorted Filtered Average GPA (in descending order):")
print(sorted_filtered_avg_gpa)

if not filtered_avg_gpa.empty:
    sorted_filtered_avg_gpa = filtered_avg_gpa.sort_values(by='Current GPA', ascending=False)
    sorted_filtered_avg_gpa.plot(kind='bar', x='Part-Time Hours', y='Current GPA', legend=False)
    plt.title('Average GPA by Part-Time Hours')
    plt.xlabel('Part-Time Hours')
    plt.ylabel('Average GPA')
    plt.show()
else:
    print("No Part-Time Hours with an average GPA higher than 3.00.")
# Out:
# Average GPA for each Part-Time Hours group:
#   Part-Time Hours  Current GPA
# 0         11 - 15     2.701667
# 1         16 - 20     3.017500
# 2         21 - 25     3.023333
# 3         26 - 30     3.060000
# 4          6 - 10     2.930769
# 5             < 5     3.094444
# 6            > 35     2.844000
# 7      Don't Work     2.872286
# Filtered Average GPA (higher than 3.00):
#   Part-Time Hours  Current GPA
# 1         16 - 20     3.017500
# 2         21 - 25     3.023333
# 3         26 - 30     3.060000
# 5             < 5     3.094444
# Sorted Filtered Average GPA (in descending order):
#   Part-Time Hours  Current GPA
# 5             < 5     3.094444
# 3         26 - 30     3.060000
# 2         21 - 25     3.023333
# 1         16 - 20     3.017500

# %%
avg_gpa = df.groupby('No. Of CCAs Participated')['Current GPA'].mean().reset_index()
print("Average GPA for each No. of CCAs group:")
print(avg_gpa)

sorted_avg_gpa = avg_gpa.sort_values(by='Current GPA', ascending=False)
print("Sorted Average GPA (in descending order):")
print(sorted_avg_gpa)

plt.figure(figsize=(8, 8))
plt.pie(avg_gpa['Current GPA'], labels=avg_gpa['No. Of CCAs Participated'], autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Average GPA by No. of CCAs')
plt.show()
# Out:
# Average GPA for each No. of CCAs group:
#   No. Of CCAs Participated  Current GPA
# 0                        1     2.958750
# 1                        2     3.095385
# 2                        3     2.838750
# 3                        4     2.514000
# 4                      > 4     3.560000
# 5           Don't Have CCA     2.792857
# Sorted Average GPA (in descending order):
#   No. Of CCAs Participated  Current GPA
# 4                      > 4     3.560000
# 1                        2     3.095385
# 0                        1     2.958750
# 2                        3     2.838750
# 5           Don't Have CCA     2.792857
# 3                        4     2.514000

# %%
avg_gpa = df.groupby('Absences')['Current GPA'].mean().reset_index()
print("Average GPA for each No. of Absences group:")
print(avg_gpa)

sorted_avg_gpa = avg_gpa.sort_values(by='Current GPA', ascending=False)
print("Sorted Average GPA (in descending order):")
print(sorted_avg_gpa)


plt.figure(figsize=(8, 6))
plt.scatter(avg_gpa['Absences'], avg_gpa['Current GPA'], color='blue', s=100)
plt.title('Average GPA by Number of Class Absences')
plt.xlabel('Number of Class Absences')
plt.ylabel('Average GPA')
plt.grid(True)
plt.show()
# Out:
# Average GPA for each No. of Absences group:
#     Absences  Current GPA
# 0          0     2.983614
# 1          1     2.841667
# 2          2     2.778800
# 3          3     3.077000
# 4          4     2.711111
# 5          5     2.803571
# 6          6     2.585000
# 7          7     2.562500
# 8          8     3.250000
# 9         10     2.680000
# 10        11     2.620000
# 11        35     0.600000
# Sorted Average GPA (in descending order):
#     Absences  Current GPA
# 8          8     3.250000
# 3          3     3.077000
# 0          0     2.983614
# 1          1     2.841667
# 5          5     2.803571
# 2          2     2.778800
# 4          4     2.711111
# 9         10     2.680000
# 10        11     2.620000
# 6          6     2.585000
# 7          7     2.562500
# 11        35     0.600000

# %%
avg_gpa = df.groupby('Game Timing')['Current GPA'].mean().reset_index()
print("Average GPA for each Game Timing:")
print(avg_gpa)

filtered_avg_gpa = avg_gpa[avg_gpa['Current GPA'] > 3.00]
print("Filtered Average GPA (higher than 3.00):")
print(filtered_avg_gpa)

sorted_filtered_avg_gpa = filtered_avg_gpa.sort_values(by='Current GPA', ascending=False)
print("Sorted Filtered Average GPA (in descending order):")
print(sorted_filtered_avg_gpa)


plt.figure(figsize=(10, 6))
plt.bar(avg_gpa['Game Timing'], avg_gpa['Current GPA'], color='skyblue')
plt.xlabel('Game Timing')
plt.ylabel('Average GPA')
plt.title('Average GPA by Game Timing')
plt.xticks(avg_gpa['Game Timing'])
plt.grid(axis='y', alpha=0.75)
plt.show()
# Out:
# Average GPA for each Game Timing:
#                 Game Timing  Current GPA
# 0                         0     2.500000
# 1                      1100     2.750000
# 2                      1200     2.876667
# 3                      1230     3.015000
# 4                      1300     3.030000
# 5                      1400     3.030000
# 6                      1500     3.260000
# 7                      1600     1.830000
# 8                      1700     3.036667
# 9                      1730     3.830000
# 10                     1800     2.805294
# 11                     1840     2.970000
# 12                     1900     3.034667
# 13                     1930     3.240000
# 14                     2000     2.981111
# 15                     2030     3.070000
# 16                     2045     3.120000
# 17                     2100     2.992353
# 18                     2130     2.410000
# 19                     2200     2.806818
# 20                     2230     2.840000
# 21                     2300     3.392000
# 22                     0000     2.503750
# 23                     0020     3.500000
# 24                     0600     3.175000
# 25                     0700     2.240000
# 26                     0900     2.910000
# 27                    21 00     2.980000
# 28   Don't Play Video Games     2.830189
# 29  There is not fixed time     3.600000
# Filtered Average GPA (higher than 3.00):
#                 Game Timing  Current GPA
# 3                      1230     3.015000
# 4                      1300     3.030000
# 5                      1400     3.030000
# 6                      1500     3.260000
# 8                      1700     3.036667
# 9                      1730     3.830000
# 12                     1900     3.034667
# 13                     1930     3.240000
# 15                     2030     3.070000
# 16                     2045     3.120000
# 21                     2300     3.392000
# 23                     0020     3.500000
# 24                     0600     3.175000
# 29  There is not fixed time     3.600000
# Sorted Filtered Average GPA (in descending order):
#                 Game Timing  Current GPA
# 9                      1730     3.830000
# 29  There is not fixed time     3.600000
# 23                     0020     3.500000
# 21                     2300     3.392000
# 6                      1500     3.260000
# 13                     1930     3.240000
# 24                     0600     3.175000
# 16                     2045     3.120000
# 15                     2030     3.070000
# 8                      1700     3.036667
# 12                     1900     3.034667
# 5                      1400     3.030000
# 4                      1300     3.030000
# 3                      1230     3.015000
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\envs\c338\lib\site-packages\matplotlib\axes\_axes.py:2450, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2449 try:
# -> 2450     left = x - width / 2
#    2451 except TypeError as e:
#
# TypeError: unsupported operand type(s) for -: 'str' and 'float'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 15
#      11 print(sorted_filtered_avg_gpa)
#      14 plt.figure(figsize=(10, 6))
# ---> 15 plt.bar(avg_gpa['Game Timing'], avg_gpa['Current GPA'], color='skyblue')
#      16 plt.xlabel('Game Timing')
#      17 plt.ylabel('Average GPA')
#
# File ~\AppData\Local\anaconda3\envs\c338\lib\site-packages\matplotlib\pyplot.py:2439, in bar(x, height, width, bottom, align, data, **kwargs)
#    2435 @_copy_docstring_and_deprecators(Axes.bar)
#    2436 def bar(
#    2437         x, height, width=0.8, bottom=None, *, align='center',
#    2438         data=None, **kwargs):
# -> 2439     return gca().bar(
#    2440         x, height, width=width, bottom=bottom, align=align,
#    2441         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~\AppData\Local\anaconda3\envs\c338\lib\site-packages\matplotlib\__init__.py:1474, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1471 @functools.wraps(func)
#    1472 def inner(ax, *args, data=None, **kwargs):
#    1473     if data is None:
# -> 1474         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1476     bound = new_sig.bind(ax, *args, **kwargs)
#    1477     auto_label = (bound.arguments.get(label_namer)
#    1478                   or bound.kwargs.get(label_namer))
#
# File ~\AppData\Local\anaconda3\envs\c338\lib\site-packages\matplotlib\axes\_axes.py:2452, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2450         left = x - width / 2
#    2451     except TypeError as e:
# -> 2452         raise TypeError(f'the dtypes of parameters x ({x.dtype}) '
#    2453                         f'and width ({width.dtype}) '
#    2454                         f'are incompatible') from e
#    2455     bottom = y
#    2456 else:  # horizontal
#
# TypeError: the dtypes of parameters x (object) and width (float64) are incompatible
